# %% [markdown]
# # MD. Rafsan Jamil
# # HW- 3 ( EDA for Audi car)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('audi.csv')
df.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize  \
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
#
#    Make
# 0  audi
# 1  audi
# 2  audi
# 3  audi
# 4  audi

# %%
df.tail()
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  \
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9
#
#        engineSize  Make
# 10663         1.0  audi
# 10664         1.0  audi
# 10665         1.0  audi
# 10666         1.4  audi
# 10667         1.4  audi

# %%
df.shape
# Out:
# (10668, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10668 non-null  object
#  1   year          10668 non-null  int64
#  2   price         10668 non-null  int64
#  3   transmission  10668 non-null  object
#  4   mileage       10668 non-null  int64
#  5   fuelType      10668 non-null  object
#  6   tax           10668 non-null  int64
#  7   mpg           10668 non-null  float64
#  8   engineSize    10668 non-null  float64
#  9   Make          10668 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 833.6+ KB

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize', 'Make'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# Make            0
# dtype: int64

# %%
sns.pairplot(df)

# %%
sns.countplot(x=df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='count'>

# %% [markdown]
# # Observations

# %%
pivot = df.pivot_table(index=['mileage'], values=['price'], aggfunc='sum')

print (pivot)
# Out:
#            price
# mileage
# 1          69000
# 5          19850
# 7          21400
# 9          55400
# 10       2969048
# ...          ...
# 146604      4495
# 148000      3990
# 152034      2490
# 168017      6195
# 323000      2490
#
# [7725 rows x 1 columns]

# %%
pivot = df.pivot_table(index=['year'], values=['price'], aggfunc='sum')

print (pivot)
# Out:
#          price
# year
# 1997      4650
# 1998      4999
# 2002      4866
# 2003     20450
# 2004     25268
# 2005     24435
# 2006     58492
# 2007    117204
# 2008    131910
# 2009    144485
# 2010    231171
# 2011    420406
# 2012    838169
# 2013   3402020
# 2014   6209125
# 2015  15113107
# 2016  33208736
# 2017  38606393
# 2018  22720355
# 2019  97223175
# 2020  25752420

# %%
pivot = df.pivot_table(index=['model'], values=['price'], aggfunc='sum')

print (pivot)
# Out:
#           price
# model
#  A1    19299480
#  A2        2490
#  A3    33581039
#  A4    27972777
#  A5    20795015
#  A6    16976148
#  A7     3521593
#  A8     4127858
#  Q2    18508954
#  Q3    32589954
#  Q5    26700869
#  Q7    17780963
#  Q8     4147936
#  R8     2734262
#  RS3    1123667
#  RS4    1554700
#  RS5    1486691
#  RS6    2182591
#  RS7      33490
#  S3      366830
#  S4      374977
#  S5       47940
#  S8      135231
#  SQ5     502653
#  SQ7     394152
#  TT     7319576

# %%
pivot = df.pivot_table(index=['model'], values=['price'], aggfunc=np.mean)

print (pivot)
# Out:
#               price
# model
#  A1    14327.750557
#  A2     2490.000000
#  A3    17408.522032
#  A4    20255.450398
#  A5    23577.114512
#  A6    22695.385027
#  A7    28865.516393
#  A8    34981.847458
#  Q2    22516.975669
#  Q3    22999.261821
#  Q5    30445.688712
#  Q7    44788.319899
#  Q8    60115.014493
#  R8    97652.214286
#  RS3   34050.515152
#  RS4   50151.612903
#  RS5   51265.206897
#  RS6   55963.871795
#  RS7   33490.000000
#  S3    20379.444444
#  S4    31248.083333
#  S5    15980.000000
#  S8    33807.750000
#  SQ5   31415.812500
#  SQ7   49269.000000
#  TT    21784.452381

# %%
table.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='price'>

# %%
plt.figure(figsize=(20,18))
sns.countplot(x='price',data=df ,order=df['price'].value_counts().index)
plt.xticks(rotation=90)
plt.show()

# %%
df.hist(figsize=(8,8),bins=40)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,8))
ax.scatter(df['mileage'],df['price'])
ax.set_xlabel('mileage')
ax.set_ylabel('price')
ax.set_title('mileage vs price')
plt.show()

# %%
sns.lineplot(x='engineSize',y='price',data=df)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
raf=df.groupby('transmission')[['mileage','price']].sum().sort_values(by='price',ascending=False)
raf[:].plot.bar(color=['red','blue'],figsize=(8,6))
plt.title('Price increase or decrease with mileage')
plt.xlabel('transmission')
plt.ylabel('price')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.title('Price in year')
sns.barplot(x='year',y='price',data=df,order=df['year'].value_counts().index,palette='rocket')
plt.xlabel('year',fontsize=10)
plt.show()

# %%
raf=df.groupby('model')[['price']].sum().sort_values(by='price',ascending=False)
raf[:].plot.bar(color=['red','blue'],figsize=(8,6))
plt.title('Price increase or decrease with model')
plt.xlabel('model')
plt.ylabel('price')
plt.show()

# %% [markdown]
# # Comments From the Observations

# %% [markdown]
# New cars have high price
#
# semi automatic car has more price but less mileage
#
# manual car has high mileage
#
# If Engine size is bigger than the price will increase

# %% [markdown]
# 1.A3,Q3, A4, Q5, A5 are the top 5 models
#
# 2.Average sells of the top 5 models :
#
# A3	17408.522032
# A5	23577.114512
# A4	20255.450398
# Q3	22999.261821
# Q5	30445.688712
#
# 3.Total sells of the top 5 models :
#
# A3     33581039
# A4     27972777
# A5     20795015
# Q3     32589954
# Q5     26700869
